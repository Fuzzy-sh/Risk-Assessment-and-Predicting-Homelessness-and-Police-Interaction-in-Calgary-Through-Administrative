# %%
import pandas as pd
import numpy as np
import os

# %%
'''

1- creating a list of file names 
2- Open file_final in write mode
3- merge the context of the files 
4 write the results in the file_final
5- delete all the files
'''

files_dir="../data/RF/"
# Creating a list of filenames
file_list=os.listdir("../data/RF/")
file_list=[file for file in file_list if (len(file.split('.'))>1) and file.split('.')[1]=='csv' ]


# Open file_final in write mode
with open('RF_results.csv', 'w') as outfile:
    outfile.write('file_num,bootstrap,max_depth,max_features,min_samples_leaf,min_samples_split,n_estimators,criterion,roc_auc, F1,recall,precision')
    outfile.write("\n")
    # Iterate through list
    for names in file_list:

        # Open each file in read mode
        with open(files_dir+names) as infile:
#             print(names.split('.')[0]+','+infile.read())
            # read the data from file1 and
            # file2 and write it in file3
            outfile.write(names.split('.')[0]+','+infile.read())


        # Add '\n' to enter data of file2
        # from next line
        outfile.write("\n")

# for file in file_list:
#     os.remove(files_dir+file)

# %%
pd.options.display.max_seq_items=10000

# %%
f=pd.read_csv('RF_results.csv')

# %%
f
# Out:
#       file_num  bootstrap  max_depth max_features  min_samples_leaf  \
# 0          545       True         10         log2                 4
# 1          223       True         10         sqrt                 8
# 2         4817       True         80         sqrt                 2
# 3         4803       True         80         sqrt                 8
# 4          237       True         10         sqrt                 8
# ...        ...        ...        ...          ...               ...
# 6475      3813       True         60         log2                 4
# 6476       548       True         10         log2                 4
# 6477      1962       True         40         log2                 8
# 6478      1976       True         40         log2                 8
# 6479      3807       True         60         log2                 4
#
#       min_samples_split  n_estimators criterion  roc_auc     F1  recall  \
# 0                    10           800   entropy    0.871  0.254   0.840
# 1                    10          1000   entropy    0.874  0.261   0.845
# 2                    10          1400   entropy    0.640  0.392   0.284
# 3                    10          1800   entropy    0.775  0.439   0.571
# 4                     5           600   entropy    0.874  0.263   0.843
# ...                 ...           ...       ...      ...    ...     ...
# 6475                  5          1800   entropy    0.728  0.454   0.468
# 6476                 10          1200   entropy    0.871  0.255   0.840
# 6477                  5          2000   entropy    0.780  0.407   0.587
# 6478                  5          1800   entropy    0.780  0.408   0.587
# 6479                  5          1200   entropy    0.728  0.457   0.468
#
#       precision
# 0         0.150
# 1         0.155
# 2         0.632
# 3         0.356
# 4         0.155
# ...         ...
# 6475      0.441
# 6476      0.150
# 6477      0.311
# 6478      0.312
# 6479      0.446
#
# [6480 rows x 12 columns]

# %%
f[(f['roc_auc']>0.86) & (f['recall']>0.85) & (f['precision']>0.1)]
# Out:
#       file_num  bootstrap  max_depth max_features  min_samples_leaf  \
# 157        425       True         10         sqrt                 8
# 238        418       True         10         sqrt                 8
# 305        168       True         10         auto                 8
# 1005       351       True         10         sqrt                 4
# 1112         1       True         10         auto                 1
# 1418       420       True         10         sqrt                 8
# 1762       122       True         10         auto                 4
# 2169       135       True         10         auto                 4
# 2349       108       True         10         auto                 4
# 2574       130       True         10         auto                 4
# 2897       286       True         10         sqrt                 2
# 3069       481       True         10         log2                 8
# 4873       216       True         10         sqrt                 8
# 5371       611       True         10         log2                 8
# 5656       228       True         10         sqrt                 8
# 6080       239       True         10         sqrt                 8
# 6092       207       True         10         auto                 8
# 6261       398       True         10         sqrt                 8
# 6304       399       True         10         sqrt                 8
# 6371       164       True         10         auto                 8
# 6383       170       True         10         auto                 8
#
#       min_samples_split  n_estimators criterion  roc_auc     F1  recall  \
# 157                  10          1400   entropy    0.878  0.265   0.851
# 238                  10           800   entropy    0.878  0.264   0.851
# 305                  10          1000   entropy    0.877  0.263   0.851
# 1005                  5          1200   entropy    0.878  0.265   0.851
# 1112                  2           400   entropy    0.878  0.265   0.851
# 1418                 10          1000   entropy    0.878  0.264   0.851
# 1762                 10          1800   entropy    0.878  0.264   0.851
# 2169                  5          1200   entropy    0.878  0.265   0.851
# 2349                 10          2000   entropy    0.878  0.266   0.851
# 2574                  5           800   entropy    0.878  0.266   0.851
# 2897                 10          2000   entropy    0.878  0.265   0.851
# 3069                 10          1600   entropy    0.875  0.255   0.851
# 4873                 10          2000   entropy    0.878  0.264   0.851
# 5371                 10          2000   entropy    0.876  0.256   0.851
# 5656                 10          1600   entropy    0.877  0.262   0.851
# 6080                  5           800   entropy    0.878  0.263   0.853
# 6092                 10          1200   entropy    0.878  0.264   0.851
# 6261                  5           600   entropy    0.877  0.262   0.851
# 6304                  5           600   entropy    0.880  0.264   0.855
# 6371                 10           600   entropy    0.878  0.265   0.851
# 6383                 10          1200   entropy    0.878  0.264   0.851
#
#       precision
# 157       0.157
# 238       0.156
# 305       0.156
# 1005      0.157
# 1112      0.157
# 1418      0.156
# 1762      0.156
# 2169      0.157
# 2349      0.157
# 2574      0.157
# 2897      0.157
# 3069      0.150
# 4873      0.156
# 5371      0.151
# 5656      0.155
# 6080      0.156
# 6092      0.156
# 6261      0.155
# 6304      0.156
# 6371      0.157
# 6383      0.157

# %%
f[ (f['precision']>0.65)]
# Out:
#       file_num  bootstrap  max_depth max_features  min_samples_leaf  \
# 1100      3560       True         60         sqrt                 2
# 1295      5503       True         90         sqrt                 2
# 3417      3519       True         60         sqrt                 2
# 4868      4188       True         70         sqrt                 2
# 4982      3552       True         60         sqrt                 2
#
#       min_samples_split  n_estimators criterion  roc_auc     F1  recall  \
# 1100                 10          1800   entropy    0.644  0.402   0.290
# 1295                 10          1600   entropy    0.644  0.402   0.290
# 3417                 10          1200   entropy    0.639  0.392   0.280
# 4868                  5          1600   entropy    0.644  0.402   0.290
# 4982                 10          1000   entropy    0.641  0.397   0.284
#
#       precision
# 1100      0.651
# 1295      0.651
# 3417      0.652
# 4868      0.651
# 4982      0.656
