# %%
import pandas as pd
import numpy as np
pd.options.display.max_seq_items=10000

'''

1- creating a list of file names 
2- Open file_final in write mode
3- merge the context of the files 
4 write the results in the file_final
5- delete all the files
'''
import os
files_dir="../data/xGBoost/"
# Creating a list of filenames
file_list=os.listdir("../data/xGBoost/")
file_list=[file for file in file_list if (len(file.split('.'))>1) and file.split('.')[1]=='csv' ]


# Open file_final in write mode
with open('xGBoos_results.csv', 'w') as outfile:
    outfile.write('file_num,max_depth,learning_rate,subsample,colsample_bytree,colsample_bylevel,n_estimators,roc_auc, F1,recall,precision')
    outfile.write("\n")
    # Iterate through list
    for names in file_list:

        # Open each file in read mode
        with open(files_dir+names) as infile:
#             print(names.split('.')[0]+','+infile.read())
            # read the data from file1 and
            # file2 and write it in file3
            outfile.write(names.split('.')[0]+','+infile.read())
#             print(names.split('.')[0])

        # Add '\n' to enter data of file2
        # from next line
        outfile.write("\n")

f=pd.read_csv('xGBoos_results.csv')

# %%
f[(f['roc_auc']>0.6) & (f['recall']>0.80) ].sort_values('recall', ascending=False)
# Out:
#       file_num  max_depth  learning_rate  subsample  colsample_bytree  \
# 4312       286          3           0.01        0.9               0.7
# 6899       310          3           0.01        0.9               0.9
# 9098       211          3           0.01        0.8               0.9
# 3221       121          3           0.01        0.8               0.9
# 9109       239          3           0.01        0.9               0.5
# ...        ...        ...            ...        ...               ...
# 4665        27          3           0.01        0.7               0.5
# 4438        32          3           0.01        0.7               0.5
# 4275       251          3           0.01        0.9               0.5
# 4180       284          3           0.01        0.9               0.7
# 9699       206          3           0.01        0.8               0.9
#
#       colsample_bylevel  n_estimators  roc_auc     F1  recall  precision
# 4312                0.9           500    0.848  0.092   0.819      0.049
# 6899                0.5           500    0.848  0.092   0.819      0.049
# 9098                0.8           500    0.848  0.092   0.819      0.049
# 3221                0.8           500    0.848  0.092   0.819      0.049
# 9109                0.5          1000    0.849  0.094   0.819      0.050
# ...                 ...           ...      ...    ...     ...        ...
# 4665                0.7          1000    0.841  0.093   0.802      0.049
# 4438                0.8          1000    0.841  0.092   0.802      0.049
# 4275                0.9          1000    0.841  0.092   0.802      0.049
# 4180                0.8          1000    0.841  0.093   0.802      0.049
# 9699                0.6          1000    0.841  0.092   0.802      0.049
#
# [313 rows x 11 columns]
